# %% [markdown]
# # Dowloading Necessary Libraries

# %%
# !pip install -q accelerate==0.21.0 peft==0.4.0 bitsandbytes==0.40.2 transformers==4.31.0 trl==0.4.7
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.9/116.9 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 22.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.5/92.5 MB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 83.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 8.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 44.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 32.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 14.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 20.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.
# sentence-transformers 3.2.1 requires transformers<5.0.0,>=4.41.0, but you have transformers 4.31.0 which is incompatible.

# %%
import os
import torch
from datasets import load_dataset, DatasetDict, Dataset, concatenate_datasets
from transformers import (
    AutoModelForSeq2SeqLM,
    AutoModelForQuestionAnswering,
    AutoModelForCausalLM,
    Seq2SeqTrainer,
    Seq2SeqTrainingArguments,
    AutoTokenizer,
    BitsAndBytesConfig,
    HfArgumentParser,
    TrainingArguments,
    pipeline,
    logging,
)
from peft import LoraConfig, PeftModel
from trl import SFTTrainer

# %% [markdown]
# # Defining Q-LoRa Parameters

# %%
# Base Model
model_name = "NousResearch/Llama-2-7b-chat-hf"

# Your Fine-tuned model name
new_model2 = "Llama-2-7b-chat-finetune"

################################################################################
# QLoRA parameters
################################################################################

# LoRA attention dimension
lora_r = 64

# Alpha parameter for LoRA scaling
lora_alpha = 16

# Dropout probability for LoRA layers
lora_dropout = 0.1

################################################################################
# bitsandbytes parameters
################################################################################

# Activate 4-bit precision base model loading
use_4bit = True

# Compute dtype for 4-bit base models
bnb_4bit_compute_dtype = "float16"

# Quantization type (fp4 or nf4)
bnb_4bit_quant_type = "nf4"

# Activate nested quantization for 4-bit base models (double quantization)
use_nested_quant = False

################################################################################
# TrainingArguments parameters
################################################################################

# Output directory where the model predictions and checkpoints will be stored
output_dir = "./results"

# Number of training epochs
num_train_epochs = 1

# Enable fp16/bf16 training (set bf16 to True with an A100)
fp16 = False
bf16 = False

# Batch size per GPU for training
per_device_train_batch_size = 4

# Batch size per GPU for evaluation
per_device_eval_batch_size = 4

# Number of update steps to accumulate the gradients for
gradient_accumulation_steps = 1

# Enable gradient checkpointing
gradient_checkpointing = True

# Maximum gradient normal (gradient clipping)
max_grad_norm = 0.3

# Initial learning rate (AdamW optimizer)
learning_rate = 2e-4

# Weight decay to apply to all layers except bias/LayerNorm weights
weight_decay = 0.001

# Optimizer to use
optim = "paged_adamw_32bit"

# Learning rate schedule
lr_scheduler_type = "cosine"

# Number of training steps (overrides num_train_epochs)
max_steps = -1

# Ratio of steps for a linear warmup (from 0 to learning rate)
warmup_ratio = 0.03

# Group sequences into batches with same length
# Saves memory and speeds up training considerably
group_by_length = True

# Save checkpoint every X updates steps
save_steps = 0

# Log every X updates steps
logging_steps = 25

################################################################################
# SFT parameters
################################################################################

# Maximum sequence length to use
max_seq_length = None

# Pack multiple short examples in the same input sequence to increase efficiency
packing = False

# Load the entire model on the GPU 0
device_map = {"": 0}

# %% [markdown]
# # Data Loading and Transformation

# %%
from datasets import load_dataset, DatasetDict

# Load the dataset
dataset = load_dataset("ShenLab/MentalChat16K")

# Split the dataset into train and test
train_test_split = dataset['train'].train_test_split(test_size=0.2)
train_dataset = train_test_split['train']
test_dataset = train_test_split['test']


train_valid_split = train_dataset.train_test_split(test_size=0.1)
train_dataset = train_valid_split["train"]
validation_dataset = train_valid_split["test"]

# Combine into a DatasetDict
split_dataset = DatasetDict({
    "train": train_dataset,
    "validation": validation_dataset,
    "test": test_dataset
})

print(split_dataset)
dataset = split_dataset
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/3.58k [00:00<?, ?B/s]
# Interview_Data_6K.csv:   0%|          | 0.00/13.6M [00:00<?, ?B/s]
# Synthetic_Data_10K.csv:   0%|          | 0.00/32.8M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/16084 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 11580
#     })
#     validation: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 1287
#     })
#     test: Dataset({
#         features: ['instruction', 'input', 'output'],
#         num_rows: 3217
#     })
# })

# %%
#function to transform prompt
def transform_example(example):

    instruction = example['instruction'].strip()
    input_text = example['input'].strip() if example['input'] else ""
    output_text = example['output'].strip()


    if input_text:
        formatted_text = f"<s>[INST] {instruction} {input_text} [/INST] {output_text} </s>" #for cases when ther's no INST
    else:
        formatted_text = f"<s>[INST] {instruction} [/INST] {output_text} </s>"

    return {'text': formatted_text}

# transformer function call
transformed_dataset = DatasetDict({
    split: data.map(transform_example, remove_columns=data.column_names)
    for split, data in dataset.items()
})

print(transformed_dataset['train'][0]['text'])
# Out:
# Map:   0%|          | 0/11580 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1287 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3217 [00:00<?, ? examples/s]
# <s>[INST] You are a helpful mental health counselling assistant, please answer the mental health questions based on the patient's description.
# The assistant gives helpful, comprehensive, and appropriate answers to the user's questions. Can you explain more about exposure therapy and whether it could be beneficial for someone with anxiety like me? I've heard mixed opinions about it, and I'm not sure if it would be a suitable approach for my specific situation. [/INST] Exposure therapy is a type of treatment that can be beneficial for individuals with anxiety. It involves gradually exposing yourself to the things or situations that trigger your anxiety in a controlled and safe environment. The goal is to help you become less fearful and anxious over time.
#
# One way exposure therapy works is by helping you confront your fears instead of avoiding them. By facing your anxieties, you have the opportunity to learn that they are not as threatening as they may seem. This process can lead to a reduction in anxiety symptoms and an increased sense of control.
#
# It's important to note that exposure therapy is not a one-size-fits-all approach. Its suitability depends on various factors, including the specific nature of your anxiety and your personal preferences. Some people find it very helpful, while others may not respond as positively.
#
# If you're considering exposure therapy, I would recommend discussing it further with a mental health professional who can assess your individual situation and provide personalized guidance. They will be able to determine if exposure therapy is appropriate for you and can tailor the treatment to meet your specific needs.
#
# Remember, therapy is a collaborative process, and finding the right approach may involve some trial and error. It's essential to communicate openly with your therapist about any concerns or reservations you may have. Together, you can explore different options and make informed decisions about your treatment journey. </s>

# %%
transformed_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 11580
#     })
#     validation: Dataset({
#         features: ['text'],
#         num_rows: 1287
#     })
#     test: Dataset({
#         features: ['text'],
#         num_rows: 3217
#     })
# })

# %% [markdown]
# # Training Pre-trained model for 1 epoch

# %%
# Load tokenizer and model with QLoRA configuration
compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)

# Check GPU compatibility with bfloat16
if compute_dtype == torch.float16 and use_4bit:
    major, _ = torch.cuda.get_device_capability()
    if major >= 8:
        print("=" * 80)
        print("Your GPU supports bfloat16: accelerate training with bf16=True")
        print("=" * 80)

# Load base model
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map=device_map
)
model.config.use_cache = False
model.config.pretraining_tp = 1

# Load LLaMA tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"

# Load LoRA configuration
peft_config = LoraConfig(
    lora_alpha=lora_alpha,
    lora_dropout=lora_dropout,
    r=lora_r,
    bias="none",
    task_type="CAUSAL_LM",
)

# Set training parameters
training_arguments = TrainingArguments(
    output_dir=output_dir,
    num_train_epochs=num_train_epochs,
    per_device_train_batch_size=per_device_train_batch_size,
    gradient_accumulation_steps=gradient_accumulation_steps,
    optim=optim,
    save_steps=save_steps,
    logging_steps=logging_steps,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    fp16=fp16,
    bf16=bf16,
    max_grad_norm=max_grad_norm,
    max_steps=max_steps,
    warmup_ratio=warmup_ratio,
    group_by_length=group_by_length,
    lr_scheduler_type=lr_scheduler_type,
    report_to="tensorboard"
)

# Set supervised fine-tuning parameters
trainer = SFTTrainer(
    model=model,
    train_dataset=transformed_dataset["train"],         # train split
    eval_dataset=transformed_dataset["validation"],     # validation split
    peft_config=peft_config,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    tokenizer=tokenizer,
    args=training_arguments,
    packing=packing,
)

# Train model
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1150: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/583 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/peft/utils/other.py:102: FutureWarning: prepare_model_for_int8_training is deprecated and will be removed in a future version. Use prepare_model_for_kbit_training instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/sft_trainer.py:159: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# Map:   0%|          | 0/11580 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1287 [00:00<?, ? examples/s]
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
# /usr/local/lib/python3.10/dist-packages/torch/_dynamo/eval_frame.py:632: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. In version 2.5 we will raise an exception if use_reentrant is not passed. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
#     <div>
#
#       <progress value='2857' max='2895' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2857/2895 7:19:40 < 05:51, 0.11 it/s, Epoch 0.99/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>1.440200</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.346000</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.047500</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.899000</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.951800</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.854900</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.918800</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.828800</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.902200</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.822600</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>0.904400</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.776000</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>0.865400</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.807000</td>
#     </tr>
#     <tr>
#       <td>375</td>
#       <td>0.859200</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.776300</td>
#     </tr>
#     <tr>
#       <td>425</td>
#       <td>0.887700</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.760800</td>
#     </tr>
#     <tr>
#       <td>475</td>
#       <td>0.802700</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.761200</td>
#     </tr>
#     <tr>
#       <td>525</td>
#       <td>0.863200</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.777700</td>
#     </tr>
#     <tr>
#       <td>575</td>
#       <td>0.827300</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.728100</td>
#     </tr>
#     <tr>
#       <td>625</td>
#       <td>0.803500</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.737400</td>
#     </tr>
#     <tr>
#       <td>675</td>
#       <td>0.833500</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.730100</td>
#     </tr>
#     <tr>
#       <td>725</td>
#       <td>0.830400</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.731400</td>
#     </tr>
#     <tr>
#       <td>775</td>
#       <td>0.813500</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.767200</td>
#     </tr>
#     <tr>
#       <td>825</td>
#       <td>0.809900</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.751200</td>
#     </tr>
#     <tr>
#       <td>875</td>
#       <td>0.828000</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.723000</td>
#     </tr>
#     <tr>
#       <td>925</td>
#       <td>0.822400</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.731500</td>
#     </tr>
#     <tr>
#       <td>975</td>
#       <td>0.801500</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.737800</td>
#     </tr>
#     <tr>
#       <td>1025</td>
#       <td>0.797600</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.737900</td>
#     </tr>
#     <tr>
#       <td>1075</td>
#       <td>0.787100</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.701400</td>
#     </tr>
#     <tr>
#       <td>1125</td>
#       <td>0.792100</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.715900</td>
#     </tr>
#     <tr>
#       <td>1175</td>
#       <td>0.778500</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.721500</td>
#     </tr>
#     <tr>
#       <td>1225</td>
#       <td>0.803500</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.701000</td>
#     </tr>
#     <tr>
#       <td>1275</td>
#       <td>0.777800</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.727700</td>
#     </tr>
#     <tr>
#       <td>1325</td>
#       <td>0.783600</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.737900</td>
#     </tr>
#     <tr>
#       <td>1375</td>
#       <td>0.784600</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.740800</td>
#     </tr>
#     <tr>
#       <td>1425</td>
#       <td>0.772200</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.720700</td>
#     </tr>
#     <tr>
#       <td>1475</td>
#       <td>0.799700</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.717800</td>
#     </tr>
#     <tr>
#       <td>1525</td>
#       <td>0.779000</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.712300</td>
#     </tr>
#     <tr>
#       <td>1575</td>
#       <td>0.774900</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.736700</td>
#     </tr>
#     <tr>
#       <td>1625</td>
#       <td>0.786000</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.718600</td>
#     </tr>
#     <tr>
#       <td>1675</td>
#       <td>0.791100</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.713000</td>
#     </tr>
#     <tr>
#       <td>1725</td>
#       <td>0.794000</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.731300</td>
#     </tr>
#     <tr>
#       <td>1775</td>
#       <td>0.777000</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.694400</td>
#     </tr>
#     <tr>
#       <td>1825</td>
#       <td>0.769800</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.761400</td>
#     </tr>
#     <tr>
#       <td>1875</td>
#       <td>0.754600</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.703200</td>
#     </tr>
#     <tr>
#       <td>1925</td>
#       <td>0.744400</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.686000</td>
#     </tr>
#     <tr>
#       <td>1975</td>
#       <td>0.754300</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.703700</td>
#     </tr>
#     <tr>
#       <td>2025</td>
#       <td>0.748100</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.682600</td>
#     </tr>
#     <tr>
#       <td>2075</td>
#       <td>0.759500</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.684600</td>
#     </tr>
#     <tr>
#       <td>2125</td>
#       <td>0.773800</td>
#     </tr>
#     <tr>
#       <td>2150</td>
#       <td>0.699100</td>
#     </tr>
#     <tr>
#       <td>2175</td>
#       <td>0.780300</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.703600</td>
#     </tr>
#     <tr>
#       <td>2225</td>
#       <td>0.783200</td>
#     </tr>
#     <tr>
#       <td>2250</td>
#       <td>0.713700</td>
#     </tr>
#     <tr>
#       <td>2275</td>
#       <td>0.776300</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.701800</td>
#     </tr>
#     <tr>
#       <td>2325</td>
#       <td>0.786200</td>
#     </tr>
#     <tr>
#       <td>2350</td>
#       <td>0.692100</td>
#     </tr>
#     <tr>
#       <td>2375</td>
#       <td>0.777600</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.716900</td>
#     </tr>
#     <tr>
#       <td>2425</td>
#       <td>0.757200</td>
#     </tr>
#     <tr>
#       <td>2450</td>
#       <td>0.667000</td>
#     </tr>
#     <tr>
#       <td>2475</td>
#       <td>0.743600</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.709300</td>
#     </tr>
#     <tr>
#       <td>2525</td>
#       <td>0.756700</td>
#     </tr>
#     <tr>
#       <td>2550</td>
#       <td>0.712400</td>
#     </tr>
#     <tr>
#       <td>2575</td>
#       <td>0.754300</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.708600</td>
#     </tr>
#     <tr>
#       <td>2625</td>
#       <td>0.768700</td>
#     </tr>
#     <tr>
#       <td>2650</td>
#       <td>0.671500</td>
#     </tr>
#     <tr>
#       <td>2675</td>
#       <td>0.752800</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.689400</td>
#     </tr>
#     <tr>
#       <td>2725</td>
#       <td>0.777800</td>
#     </tr>
#     <tr>
#       <td>2750</td>
#       <td>0.694800</td>
#     </tr>
#     <tr>
#       <td>2775</td>
#       <td>0.754400</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.710800</td>
#     </tr>
#     <tr>
#       <td>2825</td>
#       <td>0.787100</td>
#     </tr>
#     <tr>
#       <td>2850</td>
#       <td>0.686200</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='2895' max='2895' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2895/2895 7:25:06, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>25</td>
#       <td>1.440200</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.346000</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.047500</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.899000</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.951800</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.854900</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>0.918800</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.828800</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.902200</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.822600</td>
#     </tr>
#     <tr>
#       <td>275</td>
#       <td>0.904400</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.776000</td>
#     </tr>
#     <tr>
#       <td>325</td>
#       <td>0.865400</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.807000</td>
#     </tr>
#     <tr>
#       <td>375</td>
#       <td>0.859200</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.776300</td>
#     </tr>
#     <tr>
#       <td>425</td>
#       <td>0.887700</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.760800</td>
#     </tr>
#     <tr>
#       <td>475</td>
#       <td>0.802700</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.761200</td>
#     </tr>
#     <tr>
#       <td>525</td>
#       <td>0.863200</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.777700</td>
#     </tr>
#     <tr>
#       <td>575</td>
#       <td>0.827300</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.728100</td>
#     </tr>
#     <tr>
#       <td>625</td>
#       <td>0.803500</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.737400</td>
#     </tr>
#     <tr>
#       <td>675</td>
#       <td>0.833500</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.730100</td>
#     </tr>
#     <tr>
#       <td>725</td>
#       <td>0.830400</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.731400</td>
#     </tr>
#     <tr>
#       <td>775</td>
#       <td>0.813500</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.767200</td>
#     </tr>
#     <tr>
#       <td>825</td>
#       <td>0.809900</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.751200</td>
#     </tr>
#     <tr>
#       <td>875</td>
#       <td>0.828000</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.723000</td>
#     </tr>
#     <tr>
#       <td>925</td>
#       <td>0.822400</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.731500</td>
#     </tr>
#     <tr>
#       <td>975</td>
#       <td>0.801500</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.737800</td>
#     </tr>
#     <tr>
#       <td>1025</td>
#       <td>0.797600</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.737900</td>
#     </tr>
#     <tr>
#       <td>1075</td>
#       <td>0.787100</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.701400</td>
#     </tr>
#     <tr>
#       <td>1125</td>
#       <td>0.792100</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.715900</td>
#     </tr>
#     <tr>
#       <td>1175</td>
#       <td>0.778500</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.721500</td>
#     </tr>
#     <tr>
#       <td>1225</td>
#       <td>0.803500</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.701000</td>
#     </tr>
#     <tr>
#       <td>1275</td>
#       <td>0.777800</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.727700</td>
#     </tr>
#     <tr>
#       <td>1325</td>
#       <td>0.783600</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.737900</td>
#     </tr>
#     <tr>
#       <td>1375</td>
#       <td>0.784600</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.740800</td>
#     </tr>
#     <tr>
#       <td>1425</td>
#       <td>0.772200</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.720700</td>
#     </tr>
#     <tr>
#       <td>1475</td>
#       <td>0.799700</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.717800</td>
#     </tr>
#     <tr>
#       <td>1525</td>
#       <td>0.779000</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.712300</td>
#     </tr>
#     <tr>
#       <td>1575</td>
#       <td>0.774900</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.736700</td>
#     </tr>
#     <tr>
#       <td>1625</td>
#       <td>0.786000</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.718600</td>
#     </tr>
#     <tr>
#       <td>1675</td>
#       <td>0.791100</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.713000</td>
#     </tr>
#     <tr>
#       <td>1725</td>
#       <td>0.794000</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.731300</td>
#     </tr>
#     <tr>
#       <td>1775</td>
#       <td>0.777000</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.694400</td>
#     </tr>
#     <tr>
#       <td>1825</td>
#       <td>0.769800</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.761400</td>
#     </tr>
#     <tr>
#       <td>1875</td>
#       <td>0.754600</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.703200</td>
#     </tr>
#     <tr>
#       <td>1925</td>
#       <td>0.744400</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.686000</td>
#     </tr>
#     <tr>
#       <td>1975</td>
#       <td>0.754300</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.703700</td>
#     </tr>
#     <tr>
#       <td>2025</td>
#       <td>0.748100</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.682600</td>
#     </tr>
#     <tr>
#       <td>2075</td>
#       <td>0.759500</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.684600</td>
#     </tr>
#     <tr>
#       <td>2125</td>
#       <td>0.773800</td>
#     </tr>
#     <tr>
#       <td>2150</td>
#       <td>0.699100</td>
#     </tr>
#     <tr>
#       <td>2175</td>
#       <td>0.780300</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.703600</td>
#     </tr>
#     <tr>
#       <td>2225</td>
#       <td>0.783200</td>
#     </tr>
#     <tr>
#       <td>2250</td>
#       <td>0.713700</td>
#     </tr>
#     <tr>
#       <td>2275</td>
#       <td>0.776300</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.701800</td>
#     </tr>
#     <tr>
#       <td>2325</td>
#       <td>0.786200</td>
#     </tr>
#     <tr>
#       <td>2350</td>
#       <td>0.692100</td>
#     </tr>
#     <tr>
#       <td>2375</td>
#       <td>0.777600</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.716900</td>
#     </tr>
#     <tr>
#       <td>2425</td>
#       <td>0.757200</td>
#     </tr>
#     <tr>
#       <td>2450</td>
#       <td>0.667000</td>
#     </tr>
#     <tr>
#       <td>2475</td>
#       <td>0.743600</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.709300</td>
#     </tr>
#     <tr>
#       <td>2525</td>
#       <td>0.756700</td>
#     </tr>
#     <tr>
#       <td>2550</td>
#       <td>0.712400</td>
#     </tr>
#     <tr>
#       <td>2575</td>
#       <td>0.754300</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.708600</td>
#     </tr>
#     <tr>
#       <td>2625</td>
#       <td>0.768700</td>
#     </tr>
#     <tr>
#       <td>2650</td>
#       <td>0.671500</td>
#     </tr>
#     <tr>
#       <td>2675</td>
#       <td>0.752800</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.689400</td>
#     </tr>
#     <tr>
#       <td>2725</td>
#       <td>0.777800</td>
#     </tr>
#     <tr>
#       <td>2750</td>
#       <td>0.694800</td>
#     </tr>
#     <tr>
#       <td>2775</td>
#       <td>0.754400</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.710800</td>
#     </tr>
#     <tr>
#       <td>2825</td>
#       <td>0.787100</td>
#     </tr>
#     <tr>
#       <td>2850</td>
#       <td>0.686200</td>
#     </tr>
#     <tr>
#       <td>2875</td>
#       <td>0.765700</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=2895, training_loss=0.7776352969681867, metrics={'train_runtime': 26722.0525, 'train_samples_per_second': 0.433, 'train_steps_per_second': 0.108, 'total_flos': 1.4908046459731968e+17, 'train_loss': 0.7776352969681867, 'epoch': 1.0})

# %% [markdown]
# # Saving Model to Goggle Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
output_dir = "/content/drive/MyDrive/llama-2-7b-chat-finetuned"

# %%
# !pip install peft
# Out:
# Requirement already satisfied: peft in /usr/local/lib/python3.10/dist-packages (0.4.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from peft) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from peft) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from peft) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft) (2.5.0+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from peft) (4.31.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.10/dist-packages (from peft) (0.21.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft) (0.4.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (2024.6.1)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (0.24.7)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (2.32.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (0.13.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (4.66.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers->peft) (2024.8.30)

# %%
from peft import PeftModel

# PeftModel
peft_model = PeftModel(model, peft_config)

# output directory path
adapter_output_dir = "/content/drive/MyDrive/llama-2-7b-chat-adapter"

# Save the LoRA adapters
peft_model.save_pretrained(adapter_output_dir)
tokenizer.save_pretrained(adapter_output_dir)  # Save tokenizer config as usual
# Out:
# ('/content/drive/MyDrive/llama-2-7b-chat-adapter/tokenizer_config.json',
#  '/content/drive/MyDrive/llama-2-7b-chat-adapter/special_tokens_map.json',
#  '/content/drive/MyDrive/llama-2-7b-chat-adapter/tokenizer.model',
#  '/content/drive/MyDrive/llama-2-7b-chat-adapter/added_tokens.json',
#  '/content/drive/MyDrive/llama-2-7b-chat-adapter/tokenizer.json')

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel, PeftConfig

# Load the base model
model = AutoModelForCausalLM.from_pretrained(model_name, load_in_4bit=True)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Load the adapter
peft_config = PeftConfig.from_pretrained(adapter_output_dir)
model = PeftModel.from_pretrained(model, adapter_output_dir)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/peft/peft_model.py:556: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   adapters_weights = torch.load(

# %%
import os

adapter_output_dir = "/content/drive/MyDrive/llama-2-7b-chat-adapter"
print("Saved files:", os.listdir(adapter_output_dir))
# Out:
# Saved files: ['README.md', 'adapter_model.bin', 'adapter_config.json', 'tokenizer_config.json', 'special_tokens_map.json', 'added_tokens.json', 'tokenizer.model', 'tokenizer.json']

# %% [markdown]
# # Hugging Face Logins & saving Trained model to Hugging Face

# %%
# !pip install huggingface_hub
from huggingface_hub import HfApi
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (0.26.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2024.9.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.66.6)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub) (2024.8.30)
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
repo_id= "DiatWork/llama2-Chat-Mental-Health"
model.push_to_hub(repo_id)
tokenizer.push_to_hub(repo_id)
# Out:
# adapter_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/DiatWork/llama2-Chat-Mental-Health/commit/5893f9cc4fcdd7e863340cd9a3b698333fabcf88', commit_message='Upload tokenizer', commit_description='', oid='5893f9cc4fcdd7e863340cd9a3b698333fabcf88', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# # Load Model from Hugging Face

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import PeftModel

base_model_name = "NousResearch/Llama-2-7b-chat-hf"  # Base model
repo_id = "DiatWork/llama2-Chat-Mental-Health"  # Repository with LoRA adapter

# Load the base model and LoRA adapter from Hugging Face
base_model = AutoModelForCausalLM.from_pretrained(base_model_name, device_map="auto", offload_folder="offload")
model = PeftModel.from_pretrained(base_model, repo_id)

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained(base_model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:797: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/583 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/26.8k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# model-00001-of-00002.safetensors:   0%|          | 0.00/9.98G [00:00<?, ?B/s]
# model-00002-of-00002.safetensors:   0%|          | 0.00/3.50G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]
# adapter_config.json:   0%|          | 0.00/453 [00:00<?, ?B/s]
# adapter_model.bin:   0%|          | 0.00/134M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/peft/peft_model.py:556: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   adapters_weights = torch.load(
# tokenizer_config.json:   0%|          | 0.00/746 [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/21.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/435 [00:00<?, ?B/s]

# %% [markdown]
# # Inference

# %%
import torch
import textwrap

# Input with Prompt
input_text = "<s>[INST] You are a helpful mental health assistant. I'm very stressed because I have a Job Interview, though I have practiced for it but this is my first interview so I'm anxious. How to deal with this stress? [/INST] "

inputs = tokenizer(input_text, return_tensors="pt").to(model.device). # Tokenize the input

# Generate response
with torch.no_grad():
    output = model.generate(**inputs, max_new_tokens=400)

decoded_output = tokenizer.decode(output[0], skip_special_tokens=True).strip() # Tokenize the output

# Presentation
if "[INST]" in decoded_output and "[/INST]" in decoded_output:
    question, model_answer = decoded_output.split("[/INST]", 1)
else:
    question, model_answer = decoded_output, ""  # Handle cases where split fails


question = "\n".join(textwrap.wrap(question, width=80))
model_answer = "\n".join(textwrap.wrap(model_answer.strip(), width=80))

print("Question:\n", question)
print("\nModel Answer:\n", model_answer)
print("\n" + "=" * 80 + "\n")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# Question:
#  [INST] You are a helpful mental health assistant. I'm very stressed because I
# have a Job Interview, though I have practiced for it but this is my first
# interview so I'm anxious. How to deal with this stress?
#
# Model Answer:
#  Hello there! 😊 I understand how you're feeling, and it's completely normal to
# feel anxious before a job interview. Here are some tips that may help you manage
# your stress and perform your best during the interview:  1. Practice relaxation
# techniques: Deep breathing, progressive muscle relaxation, and visualization can
# help calm your nerves and reduce stress. You can try these techniques before the
# interview to help you relax and focus. 2. Get enough sleep: Lack of sleep can
# exacerbate stress and anxiety. Make sure you get enough sleep the night before
# the interview to feel rested and refreshed. 3. Stay hydrated: Drink plenty of
# water throughout the day to stay hydrated and alert. Avoid caffeine and alcohol
# as they can increase anxiety. 4. Exercise: Exercise can help reduce stress and
# improve your mood. Try to do some light exercise, such as a brisk walk or some
# stretching, before the interview. 5. Positive self-talk: Encourage yourself with
# positive affirmations. Repeat phrases such as "I've prepared well for this
# interview," "I'm capable and qualified," and "I can handle this." 6. Visualize
# success: Imagine yourself acing the interview and getting the job. Visualize the
# positive outcomes and how it will feel to land your dream job. 7. Bring a
# stress-reducing item: Bring a small item that helps you relax, such as a stress
# ball, a small stone, or a lucky charm. Having something familiar with you can
# help calm your nerves. 8. Focus on the present moment: Instead of worrying about
# the future or dwelling on past mistakes, focus on the present moment.
# Concentrate on the interview questions and answer them to the
#
# ================================================================================

# %%
# Input with Prompt
input_text = "<s>[INST] You are a helpful mental health assistant. I'm very stressed because I have a group project in last semester of my college and I want to get first honours, I'm scared. Please help me cope with stress. [/INST]"

inputs = tokenizer(input_text, return_tensors="pt").to(model.device). # Tokenize the input

# Generate response
with torch.no_grad():
    output = model.generate(**inputs, max_new_tokens=200)

decoded_output = tokenizer.decode(output[0], skip_special_tokens=True).strip() # Tokenize the output

# Presentation
if "[INST]" in decoded_output and "[/INST]" in decoded_output:
    question, model_answer = decoded_output.split("[/INST]", 1)
else:
    question, model_answer = decoded_output, ""  # Handle cases where split fails


question = "\n".join(textwrap.wrap(question, width=80))
model_answer = "\n".join(textwrap.wrap(model_answer.strip(), width=80))

print("Question:\n", question)
print("\nModel Answer:\n", model_answer)
print("\n" + "=" * 80 + "\n")
# Out:
# Question:
#  [INST] You are a helpful mental health assistant. I'm very stressed because I
# have a group project in last semester of my college and I want to get first
# honours, I'm scared. Please help me cope with stress.
#
# Model Answer:
#  Of course, I'm here to help! It's completely normal to feel stressed during the
# final stretch of a semester, especially when it comes to a significant project
# like the one you're working on. Here are some strategies that may help you cope
# with stress and achieve your goal of getting first honors:  1. Break down the
# project into smaller tasks: Sometimes, feeling overwhelmed by a big project can
# be a major source of stress. To combat this, try breaking down the project into
# smaller, more manageable tasks. This will help you focus on one task at a time
# and make progress gradually. 2. Create a schedule: Once you have broken down the
# project into smaller tasks, create a schedule that outlines when you will work
# on each task. Be realistic about how long each task will take and make sure to
# include time for breaks and self-care. Sticking to a schedule can help you stay
# on track
#
# ================================================================================

# %% [markdown]
# # Evaluation

# %%
# !pip install evaluate bert_score transformers
# Out:
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Collecting bert_score
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.31.0)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.1.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from evaluate) (1.26.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from evaluate) (4.66.6)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2024.9.0)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from evaluate) (0.26.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from evaluate) (24.2)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert_score) (2.5.1+cu121)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert_score) (3.8.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (17.0.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets>=2.0.0->evaluate) (3.10.10)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->evaluate) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->evaluate) (2024.8.30)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert_score) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.0.0->bert_score) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (1.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert_score) (3.2.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (1.17.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets>=2.0.0->evaluate) (4.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert_score) (3.0.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets>=2.0.0->evaluate) (0.2.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 2.7 MB/s eta 0:00:00
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 5.5 MB/s eta 0:00:00
# Installing collected packages: bert_score, evaluate
# Successfully installed bert_score-0.3.13 evaluate-0.4.3

# %%
dataset['test']
# Out:
# Dataset({
#     features: ['instruction', 'input', 'output'],
#     num_rows: 3217
# })

# %% [markdown]
# # Testing on 50% Test Data

# %%
import textwrap
import torch
import evaluate

# 50% test data evaluation
test_data = dataset['test']
sample_size = int(0.5* len(test_data))

prompts = []
references = []

# Build prompts and references
    sample = test_data[i]
    instruction = sample['instruction']
    input_text = sample['input']
    output_text = sample['output']

    if input_text:
        prompt = f"<s>[INST] {instruction} {input_text} [/INST]"
    else:
        prompt = f"<s>[INST] {instruction} [/INST]"

    prompts.append(prompt)
    references.append(output_text)  #reference answer

# %%
# Generate responses for each prompt and format them
generated_texts = []
for prompt in prompts:
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    with torch.no_grad():
        output = model.generate(
            **inputs,
            max_new_tokens=300,
            do_sample=True,
            top_p=0.9,
            top_k=50,
            temperature=0.7,
            use_cache=False,
            pad_token_id=tokenizer.eos_token_id
        )

    # Decode the response
    decoded_output = tokenizer.decode(output[0], skip_special_tokens=True)

    # Presentation
    try:
        question, model_answer = decoded_output.split("[/INST]", 1)
    except ValueError:
        question, model_answer = decoded_output, ""


    question = "\n".join(textwrap.wrap(question, width=80))
    model_answer = "\n".join(textwrap.wrap(model_answer, width=80))

    print("Question:\n", question)
    print("\nModel Answer:\n", model_answer)
    print("\n" + "="*80 + "\n")

    # Append decoded output to generated_texts for evaluation
    generated_texts.append(decoded_output)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# overwhelming emotions, I have been practicing deep breathing exercises,
# grounding techniques, and journaling. While they occasionally provide temporary
# relief, underlying trauma-related issues persist.  In our counseling sessions, I
# would like to learn more about different therapeutic approaches to trauma
# healing. How can we work together to process and reframe my experiences? Are
# there specific strategies you recommend for managing panic attacks and reducing
# hypervigilance?
#
# Model Answer:
#    Thank you for sharing your experiences and goals with me. It takes a lot of
# courage to seek help and work towards healing from traumatic events. I'm here to
# support you every step of the way.  Firstly, it's important to understand that
# healing from trauma is a complex and ongoing process. It's not something that
# can be fixed overnight, but with the right tools and support, you can learn to
# manage your symptoms and reg
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  I've
# been feeling overwhelmed with my caregiving responsibilities towards my father
# and my son. With my father's condition worsening, I find myself having to
# dedicate most of my time to him, leaving little to no time for myself or my son.
# I feel compelled to ensure that my husband, who works hard, is taken care of as
# well. I want to make sure he comes home to a cooked meal and a clean house.
#
# Model Answer:
#    Thank you for sharing your concerns with me. It's completely understandable
# that you're feeling overwhelmed with your caregiving responsibilities,
# especially with the worsening condition of your father and the added pressure of
# ensuring your husband comes home to a comfortable and well-maintained home.
# Firstly, it's important to acknowledge that you're doing an incredible job in
# taking care of both your father and your son. Careg
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.
# Lately, I've been feeling incredibly low and hopeless. It's as if there's a dark
# cloud hanging over me all the time. It started after I went through a difficult
# breakup. I constantly blame myself for the end of the relationship and wonder
# what I did wrong. I find it hard to concentrate on anything, even tasks that
# used to bring me joy. Sleeping has become a struggle too; I either sleep too
# much or not at all. My goal in therapy is to understand why I'm feeling this way
# and learn healthy coping mechanisms to overcome this depression.
#
# Model Answer:
#    Thank you for sharing your experience with me. It sounds like you're going
# through a very challenging time, and it's completely understandable that you're
# feeling low and hopeless. The breakup you went through can be a significant life
# event that can trigger feelings of depression, anxiety, and self-blame. It's
# important to recognize that you're not alone in this experience and that there
# are many resources available to help you work through these feelings.
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.
# Doctor, I'm struggling within my marriage and hope you can offer some guidance.
# My goal is to improve our communication and understanding so that we can rebuild
# a strong bond. Lately, there has been constant tension between my spouse and me,
# leading to frequent arguments and feelings of discontentment.  The main reason
# behind these conflicts seems to be a lack of effective communication. We both
# struggle to express ourselves openly, often leading to misunderstandings and
# unaddressed concerns. For example, when discussing financial matters, instead of
# having an open conversation, we end up blaming each other for perceived mistakes
# and shortcomings.  One recent event showcased the deep-seated issues within our
# marriage. I had made plans with friends for a weekend getaway without informing
# my spouse well in advance. They became upset, feeling neglected and excluded
# from my decision-making process. This triggered a major conflict that escalated
# to questioning our commitment to one another.  These incidents highlight the
# need for more constructive ways of resolving disagreements and building trust.
# How can counseling help us navigate these challenges? Are there specific tools
# or exercises we can utilize to enhance our communication skills and create a
# healthier marital dynamic?
#
# Model Answer:
#    Thank you for sharing your concerns with me. It's completely normal to face
# challenges in any relationship, especially when it comes to communication and
# trust. I'm here to offer you support and guidance on how counseling can help you
# and your spouse work through these issues and strengthen your bond.  Firstly,
# it's important to recognize that communication is a two-way street. It's not
# just about expressing yourself but also listening actively and em
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  I've
# been taking care of my husband's financial affairs for the past five years. He
# was diagnosed with a debilitating illness, and I felt compelled to help him in
# any way I could. At first, it was manageable, but as his condition worsened, the
# demands on my time and energy grew. I've been juggling his medical appointments,
# managing our household expenses, and trying to keep up with our savings. It's
# all become too much for me. I'm constantly worried about money, and I can't
# shake the feeling that we're on the brink of financial ruin. I've tried to talk
# to my husband about this, but he insists that I'm doing a great job and that
# we'll be okay. I don't want to burden him with my fears, but I can't keep going
# like this.
#
# Model Answer:
#    Thank you for sharing your situation with me. It sounds like you have been
# shouldering a significant burden in taking care of your husband's financial
# affairs, and it's understandable that you're feeling overwhelmed and worried
# about the future.  Firstly, it's important to recognize that you are not alone
# in this situation. Many people take on the role of caregiver for their loved
# ones, and it can be incredibly challenging both phys
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.
# Another trigger for my anxiety is crowded places. Whenever I'm in a crowded
# environment, such as shopping malls or public transportation, I feel overwhelmed
# and suffocated. The noise, the people, and the lack of personal space make me
# extremely anxious. Just last week, I had to leave a store because it was too
# crowded, and I felt trapped and panicked.
#
# Model Answer:
#    Of course, I'm here to help! It sounds like you are experiencing a common
# symptom of anxiety, feeling overwhelmed and suffocated in crowded places. Here
# are some possible ways to cope with this situation:  1. Practice deep breathing
# exercises: When you start to feel anxious in a crowded place, try taking a few
# deep breaths in through your nose and out through your mouth. This can help calm
# your body
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.
# Financial difficulties have been a major source of stress for me. The constant
# worry about making ends meet and the fear of falling into debt weigh heavily on
# my mind. It's challenging to focus on anything else when financial insecurity
# looms over me, causing sleepless nights and persistent anxiety.
#
# Model Answer:
#    Of course, I'm here to help. It sounds like financial difficulties have been a
# significant source of stress for you, and it's completely understandable to feel
# overwhelmed by the constant worry about making ends meet and the fear of falling
# into debt. Financial insecurity can be incredibly taxing on both your mental and
# emotional well-being, making it challenging to focus on anything else and
# impacting your overall quality of life.  First
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  I've
# been feeling overwhelmed with the responsibility of caring for my aunt and
# managing my own emotions. I've tried to stay positive, but the stress has been
# building up. I've heard about hospice programs, but I'm not sure how to access
# them or what to expect. I've also tried online forums, but I've found it
# difficult to connect with others in a meaningful way.
#
# Model Answer:
#    Of course, I'm here to help. It's completely understandable that you're
# feeling overwhelmed with the responsibility of caring for your aunt and managing
# your own emotions. It's important to remember that you don't have to go through
# this alone.  Firstly, let's talk about hospice programs. Hospice programs are
# designed to provide support and care for individuals who are terminally ill and
# their families. These programs
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  As
# someone who identifies as LGBTQ, I face unique challenges and discrimination in
# various aspects of my life. Sometimes, it feels overwhelming to deal with
# societal expectations and prejudices. I'm interested in exploring topics such as
# self-acceptance, building resilience, and finding inclusive communities where I
# feel comfortable being myself. Can counseling provide support tailored to the
# needs of LGBTQ individuals?
#
# Model Answer:
#    Of course! As a mental health counselling assistant, I understand the unique
# challenges that LGBTQ individuals face, and I'm here to provide support and
# guidance tailored to your needs. It's completely normal to feel overwhelmed by
# societal expectations and prejudices, but know that you don't have to face these
# challenges alone.  Counseling can be incredibly beneficial in helping you build
# resilience and self
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.
# Depression seems to consume every part of my existence, and I'm unsure how to
# break free. My hope for this counseling session is to uncover the underlying
# causes of my depression and discover strategies that can offer me solace and
# healing.  A profound sadness continuously looms over me, obscuring any sense of
# happiness. Negative thoughts infiltrate my mind relentlessly, making it
# difficult to see the brightness in life. Motivation feels absent, leaving me
# stuck in a state of inertia.  An event that has significantly contributed to my
# depression was the loss of a beloved family member. The grief and void they left
# behind created an overwhelming sense of emptiness in my life, robbing it of
# meaning.  These symptoms of depression have persisted for several months now,
# and their intensity can vary. There are days when I struggle with self-care and
# maintaining personal hygiene due to an overpowering lack of energy. It feels
# like every task requires an insurmountable effort.  Family dynamics play a role
# in perpetuating my depressive state. Growing up, my parents were emotionally
# distant and unsupportive, fostering feelings of abandonment and impacting my
# ability to form healthy relationships. Their constant criticism fuels my
# negative self-image.  To cope, I've tried engaging in activities that used to
# bring me joy, but they no longer hold the same significance. Exploring
# alternative coping mechanisms could help guide me back towards a path of
# healing.  During our session, I would appreciate discussing different treatment
# options for depression. Understanding your approach as a mental health
# professional will also provide insight into how we can navigate this journey
# together. Gaining awareness of the therapeutic process will set realistic
# expectations for progress and recovery.
#
# Model Answer:
#    Thank you for sharing your experiences with me. It sounds like you're
# struggling with a profound sense of sadness and emptiness, and that the loss of
# a loved one has had a significant impact on your life. It's completely
# understandable that you're feeling stuck and struggling to find meaning and
# purpose in your life.  It's important to recognize that depression is a complex
# condition that can have many underlying causes, and it's not uncommon for
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.
# Another major source of stress is the strained relationship with my family.
# There's constant tension and conflict, which adds an extra layer of pressure to
# my already overwhelmed state. Family gatherings become anxiety-inducing events,
# as unresolved issues and past hurts resurface, making it difficult to maintain
# healthy connections.
#
# Model Answer:
#    Of course, I'm here to help. It sounds like you're experiencing a lot of
# stress and tension in your relationships with your family, which can have a
# significant impact on your mental health. It's important to remember that you
# don't have to go through this alone, and there are many resources available to
# support you.  Can you tell me more about the specific issues you're experiencing
# with your family? What are some of the unresolved
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  I've
# always been a caretaker, ever since my mother passed away when I was young. I've
# taken care of my siblings, my own children, and now my grandchildren. I've
# always found joy in nurturing others, and I want to provide a stable home
# environment for my grandkids. But the thought of going back to school and
# juggling my responsibilities is overwhelming.
#
# Model Answer:
#    Thank you for sharing your story with me. It takes a lot of strength and
# resilience to be a caretaker, especially when you've had to take on that role at
# such a young age. It's completely understandable that the thought of going back
# to school and juggling your responsibilities can feel overwhelming.  Firstly, I
# want to acknowledge the incredible work you've done in providing a stable home
# environment for your grand
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  Stress
# has become a constant presence in my life, affecting both my physical and mental
# well-being. In this counseling session, I aim to explore techniques for managing
# stress so that I can experience greater peace and balance. For example, work
# deadlines often trigger immense pressure, leading to sleep disturbances,
# decreased concentration, and irritability. The frequency of these episodes has
# increased over the past few months, leaving me emotionally drained. Is there a
# way to reframe my perspective towards stressors and find healthier ways of
# responding to them? Which relaxation exercises or mindfulness techniques would
# be beneficial for someone dealing with chronic stress?
#
# Model Answer:
#    Of course, I'm here to help! It's completely normal to feel overwhelmed and
# emotionally drained when stress becomes a constant presence in your life. Here
# are some strategies and techniques that may help you reframe your perspective
# towards stressors and find healthier ways of responding to them:  1. Practice
# self-compassion: When you're feeling stressed, it's easy to be hard on yourself.
# Try practicing
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  I've
# been feeling overwhelmed lately, and I've been struggling to find ways to take
# care of myself. The past few months have been particularly challenging for me. I
# lost my job due to company downsizing, and my relationship ended unexpectedly.
# I've been trying to keep up with my daily responsibilities, but it feels like
# I'm constantly drowning in a sea of obligations and emotions.
#
# Model Answer:
#    Of course, I'm here to help. Sorry to hear that you've been going through a
# difficult time lately. Losing a job and an unexpected end to a relationship can
# be incredibly challenging, and it's completely normal to feel overwhelmed and
# struggling to cope.  Firstly, please know that you're not alone in this. Many
# people experience similar situations, and it's important to remember that you
# don't have to go
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.
# Spirituality has become an important aspect of my life recently. I've been
# exploring different belief systems and trying to find meaning and purpose in my
# existence. I feel a deep longing for connection with something greater than
# myself, but at the same time, I'm confused about which path to follow. How can I
# reconcile my spiritual beliefs with the realities of everyday life? And how do I
# deal with doubts and uncertainties that arise along this journey?
#
# Model Answer:
#    Thank you for sharing your thoughts and feelings with me. It's completely
# normal to feel a deep longing for connection with something greater than
# yourself, especially when exploring spirituality. Reconciling spiritual beliefs
# with everyday life can be a challenging but ultimately rewarding journey. Here
# are some suggestions that may help:  1. Practice mindfulness: Mindfulness is the
# practice of being present in the moment, without judgment. It can help you stay
# ground
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  My
# partner and I have been having constant arguments lately, and it's taking a toll
# on our relationship. We seem to misunderstand each other frequently, leading to
# frustration and hurt feelings. The conflicts often escalate quickly and leave
# both of us feeling emotionally drained. I want to work on improving our
# communication and finding healthier ways to resolve our issues.
#
# Model Answer:
#    Of course, I'm here to help! It's completely normal to experience conflicts in
# any relationship, and it's great that you're recognizing the need to improve
# your communication and find healthier ways to resolve them. Here are some
# insights and suggestions based on your description:  1. What are some common
# triggers for the arguments between you and your partner? Are there any specific
# topics or situations that seem to cause the most tension? Identifying these
# triggers can
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  My
# marriage is going through a rough patch, and I want to salvage our relationship
# with the help of therapy. Communication breakdowns and increasing conflicts have
# led us to consider separation. For example, we constantly argue over even minor
# issues like household chores or spending time together. It feels as if we've
# lost the connection we once had.
#
# Model Answer:
#    Thank you for reaching out for support. It takes a lot of courage to
# acknowledge when things are not working in a relationship and to seek help. I'm
# here to listen and offer guidance.  It's important to recognize that
# communication breakdowns and conflicts are common challenges in many
# relationships, and they can be addressed through therapy. Therapy can provide a
# safe and supportive space for you and your partner to work through your issues
# and improve your communication.
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  I've
# started questioning my beliefs and searching for meaning beyond what is visible
# in everyday life. I feel a longing for something spiritual and transcendent, but
# I'm not quite sure how to integrate it into my daily existence or find what
# resonates with me. I would like to explore and deepen my spirituality through
# counseling, finding a path that aligns with my values and brings greater
# fulfillment.
#
# Model Answer:
#    Thank you for sharing your thoughts and feelings with me. It takes a lot of
# courage to explore and deepen one's spirituality, and I'm here to support you on
# this journey.  It's great that you're questioning your beliefs and searching for
# something more meaningful in life. This is a common stage in personal growth and
# can lead to a greater sense of purpose and fulfillment.  Can you tell me more
# about what you mean by
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  I've
# been feeling overwhelmed by my dad's care and the financial burden it's placing
# on me, while also dealing with a lack of support from some of my loved ones. I'm
# unsure about how to balance my responsibilities to my dad and my relationships
# with my friends and sister.
#
# Model Answer:
#    Of course, I'm here to help. It sounds like you're facing a challenging
# situation with caring for your father and dealing with the financial burden,
# while also feeling unsupported by some of your loved ones. It's completely
# understandable to feel overwhelmed and unsure of how to balance your
# responsibilities.  Firstly, it's important to recognize that you're not alone in
# this situation. Many people find themselves in a similar
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.   "I've
# been dealing with severe anxiety for quite some time now, and I hope counseling
# can help me manage it better. It feels overwhelming when situations trigger my
# anxiety, leaving me feeling helpless. The constant worry and unease affect every
# aspect of my life - from work to personal relationships."  "My symptoms include
# racing thoughts, restlessness, difficulty concentrating, muscle tension, and
# trouble sleeping. These episodes happen frequently, sometimes multiple times a
# week, and they're becoming increasingly intense. When faced with uncertainty or
# challenging situations, my anxiety often spirals out of control."  "For
# instance, just thinking about upcoming social gatherings causes me extreme
# distress. Last week, I had a panic attack at a party which made me feel
# embarrassed and isolated. Understanding the root causes of my anxiety and
# developing coping mechanisms would be incredibly beneficial for me."
#
# Model Answer:
#    Thank you for sharing your experiences with me. It takes a lot of courage to
# seek help for mental health concerns, and I'm here to support you in any way I
# can.  It's completely understandable that you're feeling overwhelmed and
# helpless when faced with situations that trigger your anxiety. It's important to
# remember that you're not alone in this, and there are many effective coping
# mechanisms and strategies that can help you
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  ...
# (Tip: If you need inspiration, think about common scenarios or situations
# related to each topic)
#
# Model Answer:
#    Of course! I'm here to help. Please provide the patient's description, and I
# will do my best to provide helpful and appropriate answers to their mental
# health questions.  For example, if the patient describes feeling overwhelmed and
# anxious about work, I might say something like:  "It sounds like you're feeling
# a lot of stress and anxiety about work right now. It's completely normal to feel
# overwhelmed in a demanding job
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  I've
# been feeling quite distant from my close friends and family members lately, and
# it's beginning to concern me. My goal in this counseling session is to explore
# why maintaining meaningful connections has been difficult for me. I've noticed
# that when I'm with others, whether it's in social gatherings or one-on-one
# conversations, I often feel disconnected and struggle to engage authentically.
# It's almost as if there's a barrier preventing me from fully opening up and
# connecting on an emotional level. How can I overcome these barriers and develop
# more fulfilling relationships?
#
# Model Answer:
#    Thank you for sharing your concerns with me. It's completely normal to feel
# distant from your loved ones from time to time, and it's great that you're
# taking the initiative to explore the reasons behind this feeling.  There could
# be several reasons why you're struggling to maintain meaningful connections with
# your friends and family. Here are some possibilities:  1. Social anxiety: You
# may be experiencing social anxiety, which can make it difficult for you
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  I've
# been feeling overwhelmed with my responsibilities and the loss of my connection
# to nature. I used to find joy in stargazing and taking pictures of sunsets, but
# now I'm consumed by caring for my mother. I've tried to focus on smaller
# projects, working out, and budgeting my time better, but I can't seem to make
# time for the things that bring me happiness.
#
# Model Answer:
#    Thank you for sharing your concerns with me. It sounds like you're facing a
# challenging situation with caring for your mother, and it's understandable that
# it's impacting your ability to find joy in activities that used to bring you
# happiness. Here are some suggestions that may help you cope with your current
# situation:  1. Prioritize self-care: It's essential to take care of yourself
# during difficult times. Make sure to get enough sleep,
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  Hi
# there, I am struggling with depression and could really use some help navigating
# through this tough phase. My main goal during this counseling session is to
# develop effective strategies to alleviate my depressive symptoms and improve my
# overall mood. Lately, I have been feeling extremely down, losing interest in
# activities I used to enjoy, and experiencing a general sense of hopelessness.
# One specific event that triggered these feelings was the loss of my job about
# two months ago. Since then, I have found it increasingly difficult to motivate
# myself and maintain a positive outlook. My depression symptoms manifest as low
# energy levels, insomnia, changes in appetite, and pervasive feelings of sadness
# and emptiness. These symptoms are persistent and have been lasting for around
# six weeks now. In terms of my family dynamics, my relationships with my parents
# have been strained since I was a child due to their high expectations and
# constant criticism. I would appreciate your expertise in helping me understand
# the root causes of my depression, exploring potential coping mechanisms, as well
# as any treatment options that could be beneficial for me.
#
# Model Answer:
#    Hello there, thank you for sharing your struggles with me. It takes a lot of
# courage to seek help, and I'm here to support you every step of the way. It
# sounds like you're experiencing a very challenging time, and I can understand
# how difficult it can be to cope with the loss of your job and the strained
# relationships with your parents.  Firstly, it's important to recognize that
# depression is a common and treatable condition
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.
# Depression has taken a toll on my overall well-being, and attending therapy is
# part of my journey towards healing. I often experience a persistent feeling of
# sadness and hopelessness, making it difficult for me to find joy in activities I
# used to love. Even getting out of bed in the morning feels like an overwhelming
# task. I've also noticed changes in my appetite and sleep patterns - either
# sleeping excessively or struggling to fall asleep at all. It feels like a dark
# cloud is hanging over me, and I want to learn how to see glimpses of light
# again.
#
# Model Answer:
#    Thank you for sharing your experiences with me. It takes a lot of courage to
# seek help and open up about your struggles, and I'm here to support you every
# step of the way.  Firstly, it's important to acknowledge that depression is a
# common and treatable condition. It's not something that you can simply "snap out
# of," but rather a complex mental health disorder that affects millions of people
# worldwide. It's completely
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.
# Lately, I've been questioning my own sexuality, and it's causing me a lot of
# confusion and anxiety. I've always identified as straight, but recently I've
# started having feelings for someone of the same gender. I'm not sure what this
# means or how to navigate these emotions. I feel scared to talk about it with
# anyone because I'm afraid of judgment or rejection. I just need some guidance
# and support to understand myself better.
#
# Model Answer:
#    Thank you for sharing your feelings with me. It takes a lot of courage to
# confront and question one's sexuality, and I'm here to listen and offer support.
# It's important to recognize that sexuality is a complex and multifaceted aspect
# of a person's identity, and it's completely normal to experience shifts and
# changes in one's sexual feelings and desires throughout life.  Firstly, it's
# important to acknowledge that
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  Thank
# you for your guidance and support. I feel more equipped to handle the challenges
# of caregiving now that I have a better understanding of the importance of self-
# care and the resources available to me. I'm looking forward to joining a support
# group and making self-care a priority in my life.
#
# Model Answer:
#    As a mental health counselling assistant, I'm glad to hear that you're taking
# steps to prioritize your own mental health and well-being as a caregiver. It's
# essential to recognize that caring for someone else can be incredibly
# challenging and emotionally draining, and it's crucial to take care of yourself
# as well.  Can you tell me more about your experience as a caregiver? What kind
# of support
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  Stress
# has been wreaking havoc on both my physical and mental well-being. One specific
# symptom that has emerged recently is frequent migraines. These headaches are
# debilitating and force me to retreat to a dark room until they subside. They're
# accompanied by nausea, sensitivity to light and sound, and make it impossible to
# focus on anything else. These migraines have become a regular occurrence,
# impacting my productivity and overall quality of life. I'm eager to explore
# strategies to manage stress and prevent these migraines from occurring.
#
# Model Answer:
#    Thank you for sharing your concerns with me. It's completely understandable
# that the frequent migraines you're experiencing are impacting your productivity
# and overall quality of life. Stress is a common trigger for migraines, and it's
# great that you're motivated to explore strategies to manage stress and prevent
# these episodes.  Here are some potential strategies that may help you manage
# stress and reduce the frequency of migraines:  1.
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.
# Lately, I've been experiencing symptoms of depression that have made it
# difficult for me to find joy in anything. It feels like sadness engulfs me,
# leaving me emotionally numb. I struggle with basic daily tasks, as they feel
# meaningless and exhausting. Even spending time with loved ones brings no relief.
# I'm desperate to break free from this cycle and rediscover happiness and
# fulfillment in my life.
#
# Model Answer:
#    Thank you for sharing your experiences with me. It takes a lot of courage to
# open up about how you're feeling, and I'm here to listen and offer support. It
# sounds like you're going through a challenging time, and I want you to know that
# you're not alone. Many people struggle with depression, and it's important to
# remember that it's okay to feel this way.  Firstly, it's important to
# acknowledge that
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  Thank
# you for your understanding and for your support. I really appreciate your
# guidance and the reassurance that I'm not alone in this. I'll reach out to my
# family and friends, and I'll also look into connecting with crisis resources. I
# want to get better, and I'm willing to do whatever it takes to get there.
#
# Model Answer:
#    Of course, I'm here to help! It takes a lot of courage to reach out for
# support, and I'm glad you're willing to take the first step towards healing.
# Your mental health is important, and I'm here to offer you a safe and non-
# judgmental space to talk about your feelings.  Can you tell me a bit more about
# what's been going on and how you've been feeling? Sometimes it can be helpful to
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.
# Relationships   I am experiencing recurring patterns of unhealthy relationships
# and want guidance on understanding why these patterns continue to emerge.  In
# this counseling session, I aim to identify the root causes behind my destructive
# relationship patterns and develop insights to foster healthier connections.
# Feelings of frustration, self-blame, and loneliness arise as I notice similar
# patterns occurring in different relationships. Thoughts of unworthiness
# sometimes emerge, fueling a cycle that perpetuates these unhealthy dynamics.
# Specific triggering situations or events: Any signs of emotional distance,
# conflict, or perceived rejection from my partner often exacerbate feelings of
# insecurity and prompt me to engage in reactive behaviors such as clinging or
# withdrawing. Frequency, intensity, and duration of symptoms: These relationship
# patterns occur consistently across various partners, ranging from mild
# occurrences to severe ruptures. The duration can last for weeks or even months
# before the relationship reaches an unsustainable point. Discussion of
# significant life events, family dynamics, or past trauma: Experiencing
# inconsistent care during childhood due to parental issues likely influences how
# I form connections today. It has created an internalized belief system that
# contributes to repeated dysfunctional relationships. Coping strategies: To
# manage these challenges, I have sought personal therapy, engaged in self-
# reflection exercises, and started setting healthier boundaries within my
# relationships. However, these efforts are largely focused on managing the
# symptoms rather than addressing the root cause. Question posed: Can you help me
# gain insights into why these destructive patterns continue to repeat themselves?
# Also, what strategies or techniques might aid me in breaking free from these
# patterns and attracting healthier relationships?
#
# Model Answer:
#    Of course, I'm here to help you uncover the underlying reasons behind your
# recurring patterns of unhealthy relationships and develop strategies to foster
# healthier connections. Based on the information you've provided, it seems that
# your experiences of emotional distance, conflict, or perceived rejection from
# partners have led to feelings of insecurity and triggered reactive behaviors
# such as clinging or withdrawing. These patterns have been consistent across
# various relationships, and it
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  I've
# been struggling with maintaining healthy relationships, both romantic and
# platonic. My goal is to identify any patterns or unhealthy behaviors that might
# be hindering my ability to form and maintain meaningful connections with others.
# I often experience a mix of emotions such as fear, insecurity, and sadness when
# it comes to relationships. It's difficult for me to fully trust someone and let
# them into my life because I have been hurt in the past. One specific situation
# that triggered these feelings was when a close friend betrayed my trust by
# spreading rumors about me. This event shattered my confidence and made me
# question whether anyone can truly be trusted. These emotions often lead me to
# isolate myself and avoid getting too close to people, which has resulted in a
# lack of strong social support system. I would like to explore these experiences
# further and learn healthier ways to navigate relationships without constantly
# fearing abandonment or betrayal.
#
# Model Answer:
#    Thank you for sharing your experiences with me. It takes a lot of courage to
# open up about these struggles, and I'm here to listen and offer support. It's
# completely understandable that past experiences of betrayal and hurt can make it
# challenging to trust others and form meaningful connections.  Firstly, it's
# important to recognize that you're not alone in this struggle. Many people have
# experienced similar situations, and it's okay to feel the
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  I've
# been wrestling with the decision to visit my mother-in-law, torn between concern
# for her health and the disagreement with my husband about her safety. Memories
# of her last days weigh heavily on my mind, and I can't ignore the deterioration
# in her condition at 89. The stroke she suffered left her with limited strength
# in her left leg, and her sedentary lifestyle only worsens her health. I've been
# considering the best approach to approach this delicate situation.
#
# Model Answer:
#    Thank you for sharing your concerns with me. It's completely understandable
# that you're feeling torn between your concern for your mother-in-law's health
# and the disagreement with your husband about her safety. It's important to
# acknowledge that this is a complex and delicate situation, and it's okay to feel
# overwhelmed.  Firstly, it's important to recognize that your mother-in-law's
# health is of ut
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  "I
# find myself constantly worrying about every aspect of my life, even if there is
# no real reason for concern. My goal today is to gain better control over my
# anxiety and develop strategies to calm my racing thoughts."  Anxiety has become
# an unwelcome companion, never leaving my side. It feels like my mind is running
# a marathon, always anticipating catastrophe or obsessively ruminating over past
# mistakes.  Example situation: Yesterday, I received an email about a social
# gathering next month. Instead of being excited, my mind immediately started
# presenting a long list of what-ifs and worst-case scenarios. The thought of
# attending now fills me with dread.  Symptoms: Anxiety offers a constant stream
# of intrusive thoughts, accompanied by physical sensations such as muscle tension
# and restlessness. These symptoms occur multiple times a day, can be triggered by
# everyday situations, and often persist for hours at a time.  Life events: During
# my childhood, I faced various forms of rejection, which significantly impacted
# my self-esteem and contributed to my anxious disposition. While I've made
# progress, the lingering effects are impacting my present experiences.  Coping
# strategy: Currently, when overwhelmed by anxiety, I tend to seek reassurance
# from loved ones or engage in excessive planning and preparation. While these
# strategies offer brief relief, they reinforce the pattern of anxious thoughts.
# Question: How can therapy help me gain control over my racing thoughts and
# reduce unnecessary worry? Are there specific techniques you recommend for
# managing generalized anxiety?
#
# Model Answer:
#    Hello there! As a mental health counselling assistant, I'm glad you're taking
# steps towards managing your anxiety. It's completely normal to feel overwhelmed
# by the constant worry and racing thoughts, but there are many strategies and
# techniques that can help you regain control and reduce unnecessary worry.
# Firstly, it's important to understand that anxiety is a normal response to
# stress and uncertainty, and it's not something that you can
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  Hey,
# I've been feeling really low and hopeless these past few weeks. Even simple
# ...
# with a common dilemma: the desire for deeper, more intimate relationships while
# also feeling isolated and unhappy with your current social situation. Let's
# explore some possible factors contributing to this issue and discuss strategies
# that may help you improve your social connections and overall well-being.  1.
# Understanding your preferences: It's important to acknowledge and respect your
# preference for
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  (sighs
# deeply) I understand, but it's hard for me to plan when I don't have a
# definitive appointment. My anxiety spikes when I don't have a clear sense of
# what's coming up. I've been trying to manage my symptoms through mindfulness
# practices and therapy exercises, but it feels like I'm just treading water. I've
# been dealing with these feelings for years, but they've been particularly
# intense since my breakup last fall. I've been reliving the pain and regret, and
# it's been consuming me. I've tried reaching out to friends and family, but they
# don't seem to understand the depth of my emotions. I feel so alone and helpless.
#
# Model Answer:
#    Of course, I'm here to help. It sounds like you're struggling with a lot of
# anxiety and emotional pain, and it's completely understandable that you feel
# alone and helpless. It's important to recognize that you don't have to go
# through this alone, and there are many resources available to help you manage
# your symptoms and work through your feelings.  Firstly, it's important to
# acknowledge that it's okay to
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  Thank
# you for seeing me today. I am seeking assistance in managing my anxiety
# symptoms, particularly related to health concerns. Whenever I experience even
# the slightest physical discomfort, my mind automatically jumps to worst-case
# scenarios. Just last week, I felt a sharp pain in my chest and immediately
# thought I was having a heart attack. This triggered an episode of intense panic,
# and I rushed to the emergency room only to be told it was likely due to muscle
# strain. These anxieties surrounding my health have become increasingly
# disruptive lately, impacting my ability to relax and enjoy life. If possible, I
# would appreciate any guidance or coping mechanisms you could share with me to
# alleviate these fears.
#
# Model Answer:
#    Of course, I'm here to help. It's completely understandable to feel anxious
# when we experience physical discomfort, as our brain is wired to prioritize
# safety and protection. However, it's important to recognize that the likelihood
# of a serious health issue is often much lower than what our mind might suggest.
# Here are some strategies that may help you manage your anxiety and reduce the
# likelihood of catastrophic thinking:  1
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.    I've
# been feeling really lonely lately and I hope through counseling, I can learn how
# to improve my social relationships and make meaningful connections with people.
# It seems like no matter how hard I try, I struggle to build and maintain
# friendships. I often feel left out and excluded from social gatherings, which
# makes me question what's wrong with me.  I think the root of this issue stems
# from my childhood experiences. Growing up, I moved around a lot due to my
# parents' job, so I never had the opportunity to form long-lasting friendships.
# This has made it difficult for me to trust others and open up emotionally.   For
# example, just last week, there was a small gathering at work that everyone
# seemed excited about. I tried to be friendly and approachable, but I ended up
# feeling invisible as everyone else enjoyed each other's company. It stirred up
# feelings of rejection and inadequacy in me, leaving me questioning why I always
# seem to be on the outside looking in.  The frequency of these emotions varies
# depending on the situation, but recently, they have been more frequent and
# intense. I find myself constantly overanalyzing conversations and doubting my
# self-worth. These thoughts and feelings often consume my mind, leading to
# increased anxiety levels and difficulty concentrating on other areas of my life.
# In addition to my past experiences, I believe my lack of assertiveness might
# also play a role in my struggles with social relationships. I often second-guess
# myself, fear judgment, and avoid expressing my needs or opinions. It would be
# helpful to explore practical strategies to overcome this aspect as well.  During
# our sessions, I would appreciate guidance on building my self-confidence,
# improving my communication skills, and finding ways to foster meaningful
# connections with others. Is there anything specific we can work on together?
#
# Model Answer:
#    Thank you for sharing your experiences and concerns with me. It takes a lot of
# courage to seek help and work on improving your mental health, and I'm here to
# support you every step of the way.  From what you've shared, it sounds like
# you've been struggling with feelings of loneliness and social isolation for some
# time, which can be incredibly challenging and impactful on your mental health.
# It's understandable that you feel like you
#
# ================================================================================
#
# Question:
#  [INST] You are a helpful mental health counselling assistant, please answer the
# mental health questions based on the patient's description.  The assistant gives
# helpful, comprehensive, and appropriate answers to the user's questions.  I'm
# having trouble maintaining healthy relationships, and it's causing me a lot of
# distress. My goal for counseling is to better understand why I struggle so much
# in my relationships and learn how to build healthier connections.  Recently,
# I've noticed that I tend to attract partners who are emotionally unavailable or
# uninterested in commitment. This pattern has left me feeling constantly rejected
# and questioning my self-worth. For example, in my last relationship, my partner
# would often ignore my needs and dismiss my feelings, which made me feel unheard
# and insignificant.  These experiences have triggered a range of emotions within
# me. I often find myself feeling anxious and insecure in relationships, worrying
# about being abandoned or betrayed. The intensity of these emotions fluctuates
# depending on the specific situation, but they seem to persist for extended
# periods, affecting my overall well-being.  In addition to my romantic
# relationships, I also struggle with maintaining friendships. I fear being
# vulnerable and opening up to others, as past experiences have taught me that
# people can be unreliable and hurtful.   As we work together, I hope to gain
# insight into patterns that may contribute to my challenges in forming and
# sustaining healthy relationships. It would be helpful to explore any unresolved
# issues from my past that might be influencing my current behavior. Are there any
# particular techniques or strategies you recommend for improving relationships?
#
# Model Answer:
#    Thank you for sharing your experiences with me. It takes a lot of courage to
# seek help and be honest about your struggles in relationships. I'm here to
# listen and offer support.  Based on what you've shared, it sounds like you're
# struggling with feelings of insecurity and rejection in your relationships,
# which can be incredibly challenging to navigate. It's important to recognize
# that these feelings are not a reflection of your worth as a person, but
#
# ================================================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-cbb4627978e6> in <cell line: 3>()
#       4     inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
#       5     with torch.no_grad():
# ----> 6         output = model.generate(
#       7             **inputs,
#       8             max_new_tokens=100,
#
# /usr/local/lib/python3.10/dist-packages/peft/peft_model.py in generate(self, **kwargs)
#     975             self.base_model.generation_config = self.generation_config
#     976         try:
# --> 977             outputs = self.base_model.generate(**kwargs)
#     978         except:
#     979             self.base_model.prepare_inputs_for_generation = self.base_model_prepare_inputs_for_generation
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, **kwargs)
#    1586
#    1587             # 13. run sample
# -> 1588             return self.sample(
#    1589                 input_ids,
#    1590                 logits_processor=logits_processor,
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in sample(self, input_ids, logits_processor, stopping_criteria, logits_warper, max_length, pad_token_id, eos_token_id, output_attentions, output_hidden_states, output_scores, return_dict_in_generate, synced_gpus, streamer, **model_kwargs)
#    2640
#    2641             # forward pass to get next token
# -> 2642             outputs = self(
#    2643                 **model_inputs,
#    2644                 return_dict=True,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#     804
#     805         # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 806         outputs = self.model(
#     807             input_ids=input_ids,
#     808             attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#     691                 )
#     692             else:
# --> 693                 layer_outputs = decoder_layer(
#     694                     hidden_states,
#     695                     attention_mask=attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache)
#     419         residual = hidden_states
#     420         hidden_states = self.post_attention_layernorm(hidden_states)
# --> 421         hidden_states = self.mlp(hidden_states)
#     422         hidden_states = residual + hidden_states
#     423
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, x)
#     214             down_proj = sum(down_proj)
#     215         else:
# --> 216             down_proj = self.down_proj(self.act_fn(self.gate_proj(x)) * self.up_proj(x))
#     217
#     218         return down_proj
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
# !pip install rouge_score
# Initialize evaluation metrics
bleu = evaluate.load("bleu")
rouge = evaluate.load("rouge")
bertscore = evaluate.load("bertscore")

# Calculate Scores
bleu_score = bleu.compute(predictions=generated_texts, references=[[ref] for ref in references])
rouge_score = rouge.compute(predictions=generated_texts, references=references)
bert_score = bertscore.compute(predictions=generated_texts, references=references, lang="en")

# Print Results
print("BLEU Score:", bleu_score)
print("ROUGE Score:", rouge_score)
print("BERTScore (Precision, Recall, F1):", bert_score["precision"], bert_score["recall"], bert_score["f1"])


from huggingface_hub import Repository

repo = Repository(local_dir="./evaluation_results", clone_from="DiatWork/llama2-Chat-Mental-Health")

# Save metrics to JSON file
evaluation_metrics = {
    "ROUGE": rouge_score,
    "BERTScore": bert_score,
    "BLEU": bleu_score,
}

import json

output_file = "evaluation_metrics.json"

# Save the metrics to the file
with open(output_file, "w") as json_file:
    json.dump(evaluation_metrics, json_file, indent=4)
# Out:
# Requirement already satisfied: rouge_score in /usr/local/lib/python3.10/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.10/dist-packages (from rouge_score) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk->rouge_score) (4.66.6)
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.42G [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at roberta-large and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_deprecation.py:131: FutureWarning: 'Repository' (from 'huggingface_hub.repository') is deprecated and will be removed from version '1.0'. Please prefer the http-based alternatives instead. Given its large adoption in legacy code, the complete removal is only planned on next major release.
# For more details, please read https://huggingface.co/docs/huggingface_hub/concepts/git_vs_http.
#   warnings.warn(warning_message, FutureWarning)
# Cloning https://huggingface.co/DiatWork/llama2-Chat-Mental-Health into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/DiatWork/llama2-Chat-Mental-Health into local empty directory.
# BLEU Score: {'bleu': 0.0668386227741915, 'precisions': [0.4917284839463828, 0.14870607353239895, 0.06641476173765434, 0.0383716831569542], 'brevity_penalty': 0.5720646438333925, 'length_ratio': 0.6416412545579591, 'translation_length': 247234, 'reference_length': 385315}
# ROUGE Score: {'rouge1': 0.37550647846754004, 'rouge2': 0.11139243663537664, 'rougeL': 0.17264640439026438, 'rougeLsum': 0.2975981866428563}
# BERTScore: {'precision': [0.8524824380874634, 0.8520378470420837, 0.851635217666626, 0.8400753736495972, 0.8597930669784546, 0.8389649391174316, 0.8346267342567444, 0.8541004657745361, 0.8425173163414001, 0.8515846729278564, 0.8299710750579834, 0.8455315828323364, 0.8561450839042664, 0.8353731632232666, 0.8438079357147217, 0.8452134132385254, 0.8566950559616089, 0.8620609045028687, 0.8577095866203308, 0.8491437435150146, 0.872461199760437, 0.8468649387359619, 0.8443640470504761, 0.871571958065033, 0.8475203514099121, 0.8588418960571289, 0.8314037919044495, 0.8331429958343506, 0.8604621291160583, 0.8464604616165161, 0.8497201204299927, 0.8477771282196045, 0.866452693939209, 0.8516324758529663, 0.8648121356964111, 0.8489739894866943, 0.8435537815093994, 0.84283047914505, 0.853276789188385, 0.8418537378311157, 0.844724178314209, 0.8681160807609558, 0.8478083610534668, 0.8518438935279846, 0.859763503074646, 0.8446657657623291, 0.8493760228157043, 0.8475857973098755, 0.8547472953796387, 0.8478988409042358, 0.853053867816925, 0.842820405960083, 0.8426962494850159, 0.8566367626190186, 0.8486540913581848, 0.8570409417152405, 0.8547481298446655, 0.844424843788147, 0.8504884243011475, 0.8677724599838257, 0.8503934741020203, 0.8419215679168701, 0.8424016833305359, 0.8671606183052063, 0.8481580018997192, 0.8598148226737976, 0.8494182229042053, 0.855615496635437, 0.8552968502044678, 0.8458796143531799, 0.8409106731414795, 0.8723021745681763, 0.8433473110198975, 0.8462894558906555, 0.8436068296432495, 0.8433191180229187, 0.8667571544647217, 0.8579787611961365, 0.8519355654716492, 0.8506361246109009, 0.8543019890785217, 0.8514665961265564, 0.8429775238037109, 0.8527683615684509, 0.8570430278778076, 0.833289384841919, 0.8713438510894775, 0.8600298166275024, 0.8545092344284058, 0.8429673910140991, 0.8434706926345825, 0.8319342136383057, 0.8545864224433899, 0.8520216941833496, 0.865336537361145, 0.8767210245132446, 0.8546925783157349, 0.8595247268676758, 0.8496910333633423, 0.8428778648376465, 0.8503861427307129, 0.8563615083694458, 0.8593769669532776, 0.8521879315376282, 0.8413284420967102, 0.849030077457428, 0.8625048995018005, 0.8553885817527771, 0.8459692001342773, 0.8557974100112915, 0.8541123867034912, 0.8410639762878418, 0.8426525592803955, 0.8534173965454102, 0.855687141418457, 0.8484536409378052, 0.8399671316146851, 0.840088963508606, 0.8589872121810913, 0.859095573425293, 0.8348286151885986, 0.8509937524795532, 0.8606384992599487, 0.862825870513916, 0.849307119846344, 0.8425130844116211, 0.8528916239738464, 0.8615737557411194, 0.8590885400772095, 0.8616359829902649, 0.9083366990089417, 0.8630563020706177, 0.8494981527328491, 0.9116746187210083, 0.8466947078704834, 0.8635904788970947, 0.8265247344970703, 0.8582786321640015, 0.8514036536216736, 0.8565776348114014, 0.8417447805404663, 0.8523556590080261, 0.8532740473747253, 0.8513184189796448, 0.8424067497253418, 0.8455169200897217, 0.847022533416748, 0.8393109440803528, 0.8627841472625732, 0.847947895526886, 0.8833601474761963, 0.8796880841255188, 0.88103848695755, 0.8543620109558105, 0.8445894718170166, 0.8622573614120483, 0.8575084805488586, 0.8519123792648315, 0.8496705293655396, 0.8309946060180664, 0.8316720724105835, 0.8479382395744324, 0.8520744442939758, 0.8402715921401978, 0.8445245027542114, 0.8685399889945984, 0.8514611721038818, 0.839314341545105, 0.8615965247154236, 0.8429933786392212, 0.8534021973609924, 0.8322474956512451, 0.8520100116729736, 0.8424328565597534, 0.8402313590049744, 0.854526698589325, 0.8527997732162476, 0.8449939489364624, 0.836780309677124, 0.8553561568260193, 0.842447817325592, 0.8444199562072754, 0.8528012037277222, 0.8701505064964294, 0.8341468572616577, 0.8523632287979126, 0.8414155840873718, 0.8456414937973022, 0.8570828437805176, 0.8458312749862671, 0.8706443309783936, 0.8533635139465332, 0.8484287261962891, 0.8425717949867249, 0.8457107543945312, 0.8577736020088196, 0.8598041534423828, 0.851712703704834, 0.8677281737327576, 0.8713802695274353, 0.84 ...
# BLEU Score: {'bleu': 0.0668386227741915, 'precisions': [0.4917284839463828, 0.14870607353239895, 0.06641476173765434, 0.0383716831569542], 'brevity_penalty': 0.5720646438333925, 'length_ratio': 0.6416412545579591, 'translation_length': 247234, 'reference_length': 385315}
# ROUGE Score: {'rouge1': 0.37550647846754004, 'rouge2': 0.11139243663537664, 'rougeL': 0.17264640439026438, 'rougeLsum': 0.2975981866428563}
# BERTScore (Precision, Recall, F1): [0.8524824380874634, 0.8520378470420837, 0.851635217666626, 0.8400753736495972, 0.8597930669784546, 0.8389649391174316, 0.8346267342567444, 0.8541004657745361, 0.8425173163414001, 0.8515846729278564, 0.8299710750579834, 0.8455315828323364, 0.8561450839042664, 0.8353731632232666, 0.8438079357147217, 0.8452134132385254, 0.8566950559616089, 0.8620609045028687, 0.8577095866203308, 0.8491437435150146, 0.872461199760437, 0.8468649387359619, 0.8443640470504761, 0.871571958065033, 0.8475203514099121, 0.8588418960571289, 0.8314037919044495, 0.8331429958343506, 0.8604621291160583, 0.8464604616165161, 0.8497201204299927, 0.8477771282196045, 0.866452693939209, 0.8516324758529663, 0.8648121356964111, 0.8489739894866943, 0.8435537815093994, 0.84283047914505, 0.853276789188385, 0.8418537378311157, 0.844724178314209, 0.8681160807609558, 0.8478083610534668, 0.8518438935279846, 0.859763503074646, 0.8446657657623291, 0.8493760228157043, 0.8475857973098755, 0.8547472953796387, 0.8478988409042358, 0.853053867816925, 0.842820405960083, 0.8426962494850159, 0.8566367626190186, 0.8486540913581848, 0.8570409417152405, 0.8547481298446655, 0.844424843788147, 0.8504884243011475, 0.8677724599838257, 0.8503934741020203, 0.8419215679168701, 0.8424016833305359, 0.8671606183052063, 0.8481580018997192, 0.8598148226737976, 0.8494182229042053, 0.855615496635437, 0.8552968502044678, 0.8458796143531799, 0.8409106731414795, 0.8723021745681763, 0.8433473110198975, 0.8462894558906555, 0.8436068296432495, 0.8433191180229187, 0.8667571544647217, 0.8579787611961365, 0.8519355654716492, 0.8506361246109009, 0.8543019890785217, 0.8514665961265564, 0.8429775238037109, 0.8527683615684509, 0.8570430278778076, 0.833289384841919, 0.8713438510894775, 0.8600298166275024, 0.8545092344284058, 0.8429673910140991, 0.8434706926345825, 0.8319342136383057, 0.8545864224433899, 0.8520216941833496, 0.865336537361145, 0.8767210245132446, 0.8546925783157349, 0.8595247268676758, 0.8496910333633423, 0.8428778648376465, 0.8503861427307129, 0.8563615083694458, 0.8593769669532776, 0.8521879315376282, 0.8413284420967102, 0.849030077457428, 0.8625048995018005, 0.8553885817527771, 0.8459692001342773, 0.8557974100112915, 0.8541123867034912, 0.8410639762878418, 0.8426525592803955, 0.8534173965454102, 0.855687141418457, 0.8484536409378052, 0.8399671316146851, 0.840088963508606, 0.8589872121810913, 0.859095573425293, 0.8348286151885986, 0.8509937524795532, 0.8606384992599487, 0.862825870513916, 0.849307119846344, 0.8425130844116211, 0.8528916239738464, 0.8615737557411194, 0.8590885400772095, 0.8616359829902649, 0.9083366990089417, 0.8630563020706177, 0.8494981527328491, 0.9116746187210083, 0.8466947078704834, 0.8635904788970947, 0.8265247344970703, 0.8582786321640015, 0.8514036536216736, 0.8565776348114014, 0.8417447805404663, 0.8523556590080261, 0.8532740473747253, 0.8513184189796448, 0.8424067497253418, 0.8455169200897217, 0.847022533416748, 0.8393109440803528, 0.8627841472625732, 0.847947895526886, 0.8833601474761963, 0.8796880841255188, 0.88103848695755, 0.8543620109558105, 0.8445894718170166, 0.8622573614120483, 0.8575084805488586, 0.8519123792648315, 0.8496705293655396, 0.8309946060180664, 0.8316720724105835, 0.8479382395744324, 0.8520744442939758, 0.8402715921401978, 0.8445245027542114, 0.8685399889945984, 0.8514611721038818, 0.839314341545105, 0.8615965247154236, 0.8429933786392212, 0.8534021973609924, 0.8322474956512451, 0.8520100116729736, 0.8424328565597534, 0.8402313590049744, 0.854526698589325, 0.8527997732162476, 0.8449939489364624, 0.836780309677124, 0.8553561568260193, 0.842447817325592, 0.8444199562072754, 0.8528012037277222, 0.8701505064964294, 0.8341468572616577, 0.8523632287979126, 0.8414155840873718, 0.8456414937973022, 0.8570828437805176, 0.8458312749862671, 0.8706443309783936, 0.8533635139465332, 0.8484287261962891, 0.8425717949867249, 0.8457107543945312, 0.8577736020088196, 0.8598041534423828, 0.851712703704834, 0.8677281737327576, 0.871380269527 ...
# Download file adapter_model.bin:   0%|          | 8.00k/128M [00:00<?, ?B/s]
# Download file tokenizer.model:   2%|1         | 8.00k/488k [00:00<?, ?B/s]
# Clean file tokenizer.model:   0%|          | 1.00k/488k [00:00<?, ?B/s]
# Clean file adapter_model.bin:   0%|          | 1.00k/128M [00:00<?, ?B/s]

# %% [markdown]
# # Evaluation Results: BERT Avg.

# %%
import json
import numpy as np

file_path = '/content/evaluation_metrics.json'

with open(file_path, 'r') as file:
    gemma_data = json.load(file)

# Calculate Avg. BERTScore
bert_score = gemma_data["BERTScore"]

precision_avg = np.mean(bert_score["precision"])
recall_avg = np.mean(bert_score["recall"])
f1_avg = np.mean(bert_score["f1"])

precision_avg, recall_avg, f1_avg
# Out:
# (0.8533380799187945, 0.8477766775557036, 0.8504841806043998)
